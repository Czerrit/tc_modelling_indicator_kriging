# %%
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt
#import pyvista as pv
#from pyvistaqt import BackgroundPlotter
import os
import re
#import rasterio

# %%
mesh_df = pd.read_csv('C:\\Users\\Gerrit\\Desktop\\Masterarbeit\\masterarbeit_gerrit-main\\data_processed\\Daten10_processed_40.csv.csv')
mesh_list = []
mesh_df
# Out:
#      Unnamed: 0  Index           X            Y     Z  \
# 0             0    0.0  565809.623  5934327.530 -0.90
# 1             1    0.0  565809.623  5934327.530 -1.90
# 2             2    0.0  565809.623  5934327.530 -2.60
# 3             3    0.0  565809.623  5934327.530 -4.70
# 4             4    0.0  565809.623  5934327.530 -7.40
# ..          ...    ...         ...          ...   ...
# 644           3   50.0  565694.669  5934386.507 -1.44
# 645           4   50.0  565694.669  5934386.507 -2.24
# 646           5   50.0  565694.669  5934386.507 -3.14
# 647           6   50.0  565694.669  5934386.507 -5.14
# 648           7   50.0  565694.669  5934386.507 -8.14
#
#                                            description  elevation  from  \
# 0                                               Wasser       3.10   0.0
# 1                                                 Torf       3.10   4.0
# 2    Feinsand bis Mittelsand (schwach grobsandig, h...       3.10   5.0
# ...

# %%
#Querschnitt 565756E
Bohrlöcher=['BDHH_6436D1123','BDHH_6436D1059','BDHH_6436D1167','BDHH_6436D1046','BDHH_6436D79','BDHH_6436D1166','BDHH_6436D1061','BDHH_6436D1163','BDHH_6436D911','BDHH_6436D1092','BDHH_6436D1625','BDHH_6436D97']
mesh_df = mesh_df[mesh_df['id'].isin(Bohrlöcher)]
mesh_df
# Out:
#      Unnamed: 0  Index           X            Y     Z  \
# 251           0   12.0  565767.639  5934259.557   5.1
# 252           1   12.0  565767.639  5934259.557   4.7
# 253           2   12.0  565767.639  5934259.557   3.1
# 254           3   12.0  565767.639  5934259.557   2.3
# 255           4   12.0  565767.639  5934259.557   0.5
# ..          ...    ...         ...          ...   ...
# 636           6   49.0  565745.649  5934357.519  -5.6
# 637           7   49.0  565745.649  5934357.519  -7.1
# 638           8   49.0  565745.649  5934357.519  -8.0
# 639           9   49.0  565745.649  5934357.519  -9.6
# 640          10   49.0  565745.649  5934357.519 -15.0
#
#                                            description  elevation   from  \
# 251          Schwarzdecke (StraÃŸenasphalt) bis Steine       5.45   0.00
# 252  Feinsand bis Grobsand (kiesig, steinig), Bausc...       5.45   0.35
# 253                    (Ziegelreste, Beton) (TrÃ¼mmer)       5.45   0.75
# ...

# %%
df = mesh_df.drop(columns=['X','Index', 'description', 'elevation', 'totalLength','from', 'to', 'totalLength' ])

# %%
df.rename({'rockCodeShort': 'Facies'}, axis=1, inplace=True)
df
# Out:
#      Unnamed: 0            Y     Z              id Facies
# 251           0  5934259.557   5.1  BDHH_6436D1046    ygs
# 252           1  5934259.557   4.7  BDHH_6436D1046     fS
# 253           2  5934259.557   3.1  BDHH_6436D1046     yz
# 254           3  5934259.557   2.3  BDHH_6436D1046     fS
# 255           4  5934259.557   0.5  BDHH_6436D1046     fS
# ..          ...          ...   ...             ...    ...
# 636           6  5934357.519  -5.6    BDHH_6436D97      f
# 637           7  5934357.519  -7.1    BDHH_6436D97      F
# 638           8  5934357.519  -8.0    BDHH_6436D97      f
# 639           9  5934357.519  -9.6    BDHH_6436D97      f
# 640          10  5934357.519 -15.0    BDHH_6436D97      T
#
# [161 rows x 5 columns]

# %%
# Suchen und Ersetzen
neuer_name = 'y'
alter_name = 'yy', 'ygs', 'ys', 'yz'

# Ersetzen 
df['Facies'] = df['Facies'].replace(alter_name, neuer_name)

# %%
# Suchen und Ersetzen
neuer_name = 'G'
alter_name = 'mG', 'gG'

# Ersetzen
df['Facies'] = df['Facies'].replace(alter_name, neuer_name)

# %%
# Suchen und Ersetzen
neuer_name = 'H'
alter_name = 'F'

# Ersetzen 
df['Facies'] = df['Facies'].replace(alter_name, neuer_name)

# %%
# Suchen und Ersetzen
neuer_name = 'gS'
alter_name = 'fG'

# Ersetzen 
df['Facies'] = df['Facies'].replace(alter_name, neuer_name)

# %%
# Suchen und Ersetzen
neuer_name = 'S'
alter_name = 'default', 'y', 'Kl', 'brk'

# Ersetzen 
df['Facies'] = df['Facies'].replace(alter_name, neuer_name)

# %%
# Suchen und Ersetzen
neuer_name = 'fS'
alter_name = 'f'

# Ersetzen 
df['Facies'] = df['Facies'].replace(alter_name, neuer_name)

# %%
unique_entries = df['Facies'].unique()

# Ausgabe der einzigartigen Einträge
print(unique_entries)
# Out:
# ['S' 'fS' 'H' 'U' 'mS' 'G' 'gS' 'Fkm' 'Mg' 'T']

# %%
interval_size = 0.5 #m
big_new_df = pd.DataFrame()
groups = df.groupby(['id'])
for id, subdf in groups:
    subdf = subdf[::-1]
    new_df = pd.DataFrame()
    all_new_ys = []
    all_new_zs = []
    all_new_facies = []
    for i in range(len(subdf)-1):
        a = subdf['Z'].values[i]
        b = subdf['Z'].values[i+1]
        new_z = np.arange(b, a, -interval_size)[::-1]
        new_facies = list(np.repeat(subdf['Facies'].values[i], len(new_z)-1))
        new_facies.append(subdf['Facies'].values[i+1])
        new_y = np.repeat(subdf['Y'].values[i+1], len(new_z))
        for j in range(len(new_z)):
            all_new_zs.append(new_z[j])
            all_new_ys.append(new_y[j])
            all_new_facies.append(new_facies[j])

    new_df['Y'] = np.array(all_new_ys).ravel()[::-1]
    new_df['Z'] =  np.array(all_new_zs).ravel()[::-1]
    new_df['Facies'] =  np.array(all_new_facies).ravel()[::-1]
    big_new_df = pd.concat((big_new_df, new_df))

# %%
for facies in big_new_df['Facies'].unique():
    if facies in df['Facies'].unique():
        pass
    else:
        print('----', facies)

# %%
df=big_new_df
df
# Out:
#               Y     Z Facies
# 0   5934259.557   5.1      S
# 1   5934259.557   4.7     fS
# 2   5934259.557   4.2      S
# 3   5934259.557   3.7      S
# 4   5934259.557   3.2      S
# ..          ...   ...    ...
# 34  5934357.519 -12.6      T
# 35  5934357.519 -13.1      T
# 36  5934357.519 -13.6      T
# 37  5934357.519 -14.1      T
# 38  5934357.519 -14.6      T
#
# [732 rows x 3 columns]

# %%
unique_values = big_new_df['Facies'].unique()
print(unique_values)
# Out:
# [5 2 7 1 3 6 8 4 9 0]

# %%
facies_mapping = {'T':0, 'U':1, 'fS':2, 'mS':3, 'gS':4, 'S':5, 'G':6, 'H':7, 'Fkm':8, 'Mg':9}
df['Facies'] = df['Facies'].replace(facies_mapping)

# %%
df.rename({'Y': 'X', 'Z':'Y'}, axis=1, inplace=True)
df
# Out:
#               X     Y  Facies
# 0   5934259.557   5.1       5
# 1   5934259.557   4.7       2
# 2   5934259.557   4.2       5
# 3   5934259.557   3.7       5
# 4   5934259.557   3.2       5
# ..          ...   ...     ...
# 34  5934357.519 -12.6       0
# 35  5934357.519 -13.1       0
# 36  5934357.519 -13.6       0
# 37  5934357.519 -14.1       0
# 38  5934357.519 -14.6       0
#
# [732 rows x 3 columns]

# %%
folder_path = "C:\\Users\\Gerrit\\Desktop\\Masterarbeit\\masterarbeit_gerrit-main\\data_processed"  # Pfad zum Ordner
file_name = "Querschnitt565756E_perfekt.csv"
file_path = os.path.join(folder_path, file_name)

# %%
with open(file_path, mode='w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(df.columns)
    for row in df.itertuples(index=False):
        writer.writerow(row)
    print("Die Tabelle wurde als CSV-Datei gespeichert.")
# Out:
# Die Tabelle wurde als CSV-Datei gespeichert.
